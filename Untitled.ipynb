# %%
import pandas as pd

A2 = pd.read_excel('A2.xlsx')

# %%
A2['카드승인일자_1']
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#              ...
# 167097    2023-05-25
# 167098    2023-05-26
# 167099    2023-05-26
# 167100    2023-05-31
# 167101    2023-05-31
# Name: 카드승인일자_1, Length: 167102, dtype: object

# %%
A2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167102 entries, 0 to 167101
# Data columns (total 62 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   증권번호          167102 non-null  int64
#  1   임직원여부         1768 non-null    object
#  2   유입처순번         167102 non-null  int64
#  3   유입일시          161497 non-null  datetime64[ns]
#  4   유입채널디바이스구분    167102 non-null  object
#  5   유입채널대분류명      167102 non-null  object
#  6   유입채널중분류명      167102 non-null  object
#  7   매체명           167102 non-null  object
#  8   유입처코드         161497 non-null  float64
#  9   유입처명          161688 non-null  object
#  10  계약일자          167102 non-null  object
#  11  초회영수일자        167102 non-null  object
#  12  상품채널구분        167102 non-null  object
#  13  신규갱신구분        167102 non-null  object
#  14  신규갱신상세구분      163397 non-null  object
#  15  신차구분_다이렉트     167102 non-null  object
#  16  상품코드          167102 non-null  int64
# ...

# %%
A2['카드승인일자_1'] = pd.to_datetime(A2['카드승인일자_1'])

A2['카드승인일자_2'] = pd.to_datetime(A2['카드승인일자_2'])

# %%
A2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167102 entries, 0 to 167101
# Data columns (total 62 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   증권번호          167102 non-null  int64
#  1   임직원여부         1768 non-null    object
#  2   유입처순번         167102 non-null  int64
#  3   유입일시          161497 non-null  datetime64[ns]
#  4   유입채널디바이스구분    167102 non-null  object
#  5   유입채널대분류명      167102 non-null  object
#  6   유입채널중분류명      167102 non-null  object
#  7   매체명           167102 non-null  object
#  8   유입처코드         161497 non-null  float64
#  9   유입처명          161688 non-null  object
#  10  계약일자          167102 non-null  object
#  11  초회영수일자        167102 non-null  object
#  12  상품채널구분        167102 non-null  object
#  13  신규갱신구분        167102 non-null  object
#  14  신규갱신상세구분      163397 non-null  object
#  15  신차구분_다이렉트     167102 non-null  object
#  16  상품코드          167102 non-null  int64
# ...

# %%
A2_test = A2[A2['카드승인일자_1'].between('2023-05-01', '2023-05-09') | A2['카드승인일자_2'].between('2023-05-01', '2023-05-09')]
A2_test
# Out:
#                증권번호 임직원여부  유입처순번                유입일시 유입채널디바이스구분 유입채널대분류명  \
# 227     20232453291   NaN      1 2023-04-30 23:53:02     Mobile       광고
# 228     20232453292   NaN      1 2023-04-30 23:45:04  MobileApp     직접유입
# 229     20232453293   NaN      1 2023-04-30 23:55:43  MobileApp     직접유입
# 230     20232453294   NaN      1 2023-04-30 23:51:25        Web       광고
# 231     20232453295   NaN      1                 NaT         기타       기타
# ...             ...   ...    ...                 ...        ...      ...
# 63957   20232701478   NaN      1 2023-05-04 14:31:58       Call     직접유입
# 74753   20232728836   NaN      1 2023-05-09 16:03:27       Call       기타
# 75941   20232734194   NaN      1 2023-05-02 15:40:20       Call     직접유입
# 93960   20232808635   NaN      1 2023-05-08 15:27:58       Call     직접유입
# 126096  20232932649   NaN      1 2023-05-24 10:54:32       Call       제휴
#
#         유입채널중분류명         매체명         유입처코드                       유입처명  ...  \
# ...
